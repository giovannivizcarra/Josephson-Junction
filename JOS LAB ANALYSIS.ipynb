# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data0 = pd.read_csv('2019-9-18-JOS_Data-24700dot7(0).dat',delimiter='\t',skiprows = 3)
data1 = pd.read_csv('2019-9-18-JOS_Data-24700dot7(1).dat',delimiter='\t',skiprows = 3)
data2 = pd.read_csv('2019-9-18-JOS_Data-24700dot7(2).dat',delimiter='\t',skiprows = 3)
data3 = pd.read_csv('2019-9-18-JOS_Data-24700dot7(3).dat',delimiter='\t',skiprows = 3)
data4 = pd.read_csv('2019-9-18-JOS_Data-24700dot7(4).dat',delimiter='\t',skiprows = 3)
df0 = pd.DataFrame(data0, columns =['Time','X','Y'])
df1 = pd.DataFrame(data1, columns =['Time','X','Y'])
df2 = pd.DataFrame(data2, columns =['Time','X','Y'])
df3 = pd.DataFrame(data3, columns =['Time','X','Y'])
df4 = pd.DataFrame(data4, columns =['Time','X','Y'])

plt.xlim(-.1,0)
plt.ylim(-4,2)

plt.scatter(df1['X'],df1['Y'],s=1,marker = '+')
plt.scatter(df2['X'],df2['Y'],s=1,marker = '+')
plt.scatter(df3['X'],df3['Y'],s=1,marker = '+')
plt.scatter(df4['X'],df4['Y'],s=1,marker = '+')

plt.legend()
plt.grid()


plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data0 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(0).dat',delimiter='\t',skiprows = 3)
data1 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(1).dat',delimiter='\t',skiprows = 3)
data2 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(2).dat',delimiter='\t',skiprows = 3)
data3 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(3).dat',delimiter='\t',skiprows = 3)
data4 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(4).dat',delimiter='\t',skiprows = 3)
df0 = pd.DataFrame(data0, columns =['Time','X','Y'])
df1 = pd.DataFrame(data1, columns =['Time','X','Y'])
df2 = pd.DataFrame(data2, columns =['Time','X','Y'])
df3 = pd.DataFrame(data3, columns =['Time','X','Y'])
df4 = pd.DataFrame(data4, columns =['Time','X','Y'])

plt.xlim(-.1,.1)
plt.scatter(df1['X'],df1['Y'],s=.5,marker = '.')
plt.scatter(df2['X'],df2['Y'],s=.5,marker = '.')
plt.scatter(df3['X'],df3['Y'],s=.5,marker = '.')
plt.scatter(df4['X'],df4['Y'],s=.5,marker = '.')
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data0 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(0).dat',delimiter='\t',skiprows = 3)
data1 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(1).dat',delimiter='\t',skiprows = 3)
data2 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(2).dat',delimiter='\t',skiprows = 3)
data3 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(3).dat',delimiter='\t',skiprows = 3)
data4 = pd.read_csv('2019-9-18-JOS_Data-26113dot8(4).dat',delimiter='\t',skiprows = 3)
df0 = pd.DataFrame(data0, columns =['Time','X','Y'])
df1 = pd.DataFrame(data1, columns =['Time','X','Y'])
df2 = pd.DataFrame(data2, columns =['Time','X','Y'])
df3 = pd.DataFrame(data3, columns =['Time','X','Y'])
df4 = pd.DataFrame(data4, columns =['Time','X','Y'])

plt.xlim(-.1,.1)
plt.scatter(df1['X'],df1['Y'],s=.5,marker = '.')
plt.scatter(df2['X'],df2['Y'],s=.5,marker = '.')
plt.scatter(df3['X'],df3['Y'],s=.5,marker = '.')
plt.scatter(df4['X'],df4['Y'],s=.5,marker = '.')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-74-23b9f0aa61ba> in <module>()
#       8 data2 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(2).dat',delimiter='\t',skiprows = 3)
#       9 data3 = pd.read_csv('2019-9-18-JOS_Data-81346dot8(3).dat',delimiter='\t',skiprows = 3)
# ---> 10 data4 = pd.read_csv('2019-9-18-JOS_Data-26113dot8(4).dat',delimiter='\t',skiprows = 3)
#      11 df0 = pd.DataFrame(data0, columns =['Time','X','Y'])
#      12 df1 = pd.DataFrame(data1, columns =['Time','X','Y'])
#
# ...

# %%
def flatten_dataframe(df ,columns):
        total = np.array([])
        for c in columns:
            total = np.concatenate([total, df[c]])
        return total

def create_xy(df,columns):
    for c in columns:
        y = flatten_dataframe(df,columns)
    return y
def naive(l):
    m = []
    for x in l:
        for y in x:
            m.append(y)
    return m

a()
b()
c()

# %%
xaxis = []
yaxis = []
xaxis.append(df0['X'])
xaxis.append(df1['X'])
xaxis.append(df2['X'])
xaxis.append(df3['X'])
xaxis.append(df4['X'])

yaxis.append(df0['Y'])
yaxis.append(df1['Y'])
yaxis.append(df2['Y'])
yaxis.append(df3['Y'])
yaxis.append(df4['Y'])

timee.append(df0['Time'])
timee.append(df1['Time'])
timee.append(df2['Time'])
timee.append(df3['Time'])
timee.append(df4['Time'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-fe424eb9b123> in <module>()
#      13 yaxis.append(df4['Y'])
#      14
# ---> 15 timee.append(df0['Time'])
#      16 timee.append(df1['Time'])
#      17 timee.append(df2['Time'])
#
# NameError: name 'timee' is not defined

# %%
df0.to_csv("f0")
df1.to_csv("f1")
df2.to_csv("f2")
df3.to_csv("f3")
df4.to_csv("f4")

# %%
plt.xlim(-.1,0)
plt.scatter(volt,current,s=.1,marker = '.')
plt.xlabel('mV')
plt.show()
current
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-e8c398eba199> in <module>()
#       1 plt.xlim(-.1,0)
# ----> 2 plt.scatter(volt,current,s=.1,marker = '.')
#       3 plt.xlabel('mV')
#       4 plt.show()
#       5 current
#
# NameError: name 'volt' is not defined

# %%
def getcopy(df):
    xaxis = []
    yaxis = []
    xaxis.append(df['X'])
    yaxis.append(df['Y'])
    l = np.asarray(naive(xaxis)) #xaxis voltage
    xxx = np.asarray(naive(yaxis)) #yaxis current
    
    g =  np.unique(l)#([x for x in l if not l.count(x) > 3])
    li = np.zeros_like(g)
    for i in range(0,len(g)):
        test_element = xxx[l == g[i]]
        li[i] = test_element[0]
        #if len(test_element) > 1:
            #li.append(test_element[0])
        #if not l.count(l[i]) > 3:
        #    li.append(xxx[i])

    return li,g
#right is for y axis ie g ie l and it is removing repeated values from l

# %%
xaxis0 = getcopy(df0)[1]
yaxis0 =getcopy(df0)[0]

xaxis1 = getcopy(df1)[1]
yaxis1 =getcopy(df1)[0]

xaxis2 = getcopy(df2)[1]
yaxis2=getcopy(df2)[0]

xaxis3= getcopy(df3)[1]
yaxis3=getcopy(df3)[0]

xaxis4 = getcopy(df4)[1]
yaxis4=getcopy(df4)[0]

# %%
df0
# Out:
#                       Time         X         Y
# 0     9/18/2019  16:19:25.  0.014222  1.545483
# 1     9/18/2019  16:19:25.  0.015189  1.566741
# 2     9/18/2019  16:19:25.  0.014383  1.587195
# 3     9/18/2019  16:19:25.  0.012612  1.604105
# 4     9/18/2019  16:19:25.  0.012451  1.626169
# ...                    ...       ...       ...
# 2043  9/18/2019  16:19:25. -0.046010 -1.606902
# 2044  9/18/2019  16:19:25. -0.048104 -1.629771
# 2045  9/18/2019  16:19:25. -0.046976 -1.652963
# 2046  9/18/2019  16:19:25. -0.046654 -1.668262
# 2047  9/18/2019  16:19:25. -0.042628 -1.690165
#
# [2048 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline


def p(xaxis,yaxis,number):
    current = yaxis
    volt = xaxis
    currentFit = UnivariateSpline(sorted(volt),current, s= number)
    x_voltage = np.linspace(min(volt), max(volt), 9000)
    
    y_current = currentFit(x_voltage)

    return x_voltage,y_current

# %%
xaxis = []
yaxis = []
xaxis.append(df4['X'])
yaxis.append(df3['Y'])
def getcopy():
    l = np.asarray(naive(xaxis)) #xaxis voltage
    xxx = np.asarray(naive(yaxis)) #yaxis current
    
    g =  np.unique(l)#([x for x in l if not l.count(x) > 3])
    li = np.zeros_like(g)
    for i in range(0,len(g)):
        test_element = xxx[l == g[i]]
        li[i] = test_element[0]
        #if len(test_element) > 1:
            #li.append(test_element[0])
        #if not l.count(l[i]) > 3:
        #    li.append(xxx[i])

    return li,g
#right is for y axis ie g ie l and it is removing repeated values from l

# %%
p()

xaxis = []
yaxis = []
xaxis.append(df3['X'])
yaxis.append(df3['Y'])

p()

xaxis = []
yaxis = []
xaxis.append(df2['X'])
yaxis.append(df2['Y'])

p()

xaxis = []
yaxis = []
xaxis.append(df1['X'])
yaxis.append(df1['Y'])

p()

xaxis = []
yaxis = []
xaxis.append(df4['X'])
yaxis.append(df4['Y'])

p()

xaxis = []
yaxis = []
xaxis.append(df0['X'])
yaxis.append(df0['Y'])

p()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-0a7b862dd658> in <module>()
# ----> 1 p()
#       2
#       3 xaxis = []
#       4 yaxis = []
#       5 xaxis.append(df3['X'])
#
# TypeError: p() missing 3 required positional arguments: 'xaxis', 'yaxis', and 'number'

# %%
xaxis = []
yaxis = []
xaxis.append(df1['X'])
yaxis.append(df1['Y'])

p()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-b5259f10b5f5> in <module>()
#       4 yaxis.append(df1['Y'])
#       5
# ----> 6 p()
#
# TypeError: p() missing 3 required positional arguments: 'xaxis', 'yaxis', and 'number'

# %%
zipped_list = zip(xaxis0, xaxis1, xaxis2,xaxis3,xaxis4)
zipped_list1 = zip(yaxis0, yaxis1, yaxis2,yaxis3,yaxis4)
x = ([sum(item)/len(item) for item in zipped_list])
y = ([sum(item)/len(item) for item in zipped_list1])
len(x)
# Out:
# 903

# %%
x0 = p(xaxis0,yaxis0,11)[0]
y0 = p(xaxis0,yaxis0,11)[1]


x1 = p(xaxis1,yaxis1,15)[0]
y1 = p(xaxis1,yaxis1,15)[1]
plt.plot(x1,y1,'-.')
plt.xlim(-.1,.1)
plt.ylim(-4,4)

x2 = p(xaxis2,yaxis2,19)[0]
y2 = p(xaxis2,yaxis2,19)[1]

x3 = p(xaxis3,yaxis3,12)[0]
y3 = p(xaxis3,yaxis3,12)[1]

x4 = p(xaxis4,yaxis4,14)[0]
y4 = p(xaxis4,yaxis4,14)[1]

zipped_list = zip(x0, x1, x2,x3,x4)
zipped_list1 = zip(y0, y1, y2,y3,y4)
x = ([sum(item)/5 for item in zipped_list])
y = ([sum(item)/5 for item in zipped_list1])

# %%
import matplotlib.pyplot as plt

# x coordinates for the lines





def g(xaxis,yaxis,n):
    x1 = p(xaxis,yaxis,n)[0]
    y1 = p(xaxis,yaxis,n)[1]
    plt.scatter(xaxis4,yaxis4,s = 1, color = 'r')
    plt.plot(x1,y1,'-.', color='b')
    plt.xlim(-.1,.1)
    plt.ylim(-4,4)
    #xcoords = [-0.1, -.08, -.06,-.04,-.02,0,.02,.04,.06,.1]

   # for xc in xcoords:
        #plt.axvline(x=xc,linewidth=.5)
    

g(xaxis0,yaxis0,11)
plt.show()
g(xaxis1,yaxis1,15)
plt.show()

g(xaxis2,yaxis2,19)
plt.show()

g(xaxis3,yaxis3,12)
plt.show()

g(xaxis4,yaxis4,14)

# %%
x0 = p(xaxis0,yaxis0)[0]
y0 = p(xaxis0,yaxis0)[1]


x1 = p(xaxis1,yaxis1)[0]
y1 = p(xaxis1,yaxis1)[1]

x2 = p(xaxis2,yaxis2)[0]
y2 = p(xaxis2,yaxis2)[1]

x3 = p(xaxis3,yaxis3)[0]
y3 = p(xaxis3,yaxis3)[1]

x4 = p(xaxis4,yaxis4)[0]
y4 = p(xaxis4,yaxis4)[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-5f6e2c46f252> in <module>()
# ----> 1 x0 = p(xaxis0,yaxis0)[0]
#       2 y0 = p(xaxis0,yaxis0)[1]
#       3
#       4
#       5 x1 = p(xaxis1,yaxis1)[0]
#
# TypeError: p() missing 1 required positional argument: 'number'

# %%
x1 = p(xaxis1,yaxis1)[0]
y1 = p(xaxis1,yaxis1)[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-7d0a039e59c4> in <module>()
#       1
# ----> 2 x1 = p(xaxis1,yaxis1)[0]
#       3 y1 = p(xaxis1,yaxis1)[1]
#
# TypeError: p() missing 1 required positional argument: 'number'

# %%
x4 = [.1-.08,.075-.065,.065-.035,.035-.02,.02 - 0 ]
x4
# Out:
# [0.020000000000000004, 0.009999999999999995, 0.03, 0.015000000000000003, 0.02]

# %%
x3 = [.06-.05,.05-.035,.035-.015,.015-0,.015-0]

# %%
x2 = [.075- .050,.050-.035,.035-.015,.015-0,.02-0]

# %%
x1 = [.075-.05,.05-.025,.025-.015,.015-.01,.01-.02]

# %%
x0 = [.075-.065,.065-.035,.035-.02,.02-0,.015]
# Out:
# [0.009999999999999995, 0.03, 0.015000000000000003, 0.02, 0.015]

# %%
df = pd.DataFrame([x0,x1,x2,x3,x4],columns = None,index = ['Voltage difference between Step for Run1','Voltage difference between Step for Run2','Voltage difference between Step for Run3','Voltage difference between Step for Run4','Voltage difference between Step for Run5'])

# %%
df
# Out:
#                                               0      1      2      3      4
# Voltage difference between Step for Run1  0.010  0.030  0.015  0.020  0.015
# Voltage difference between Step for Run2  0.025  0.025  0.010  0.005 -0.010
# Voltage difference between Step for Run3  0.025  0.015  0.020  0.015  0.020
# Voltage difference between Step for Run4  0.010  0.015  0.020  0.015  0.015
# Voltage difference between Step for Run5  0.020  0.010  0.030  0.015  0.020

# %%
y = [np.mean(x0),np.mean(x1),np.mean(x2),np.mean(x3),np.mean(x4)]

# %%
data0
# Out:
#                       Time         X         Y
# 0     9/18/2019  16:19:25.  0.014222  1.545483
# 1     9/18/2019  16:19:25.  0.015189  1.566741
# 2     9/18/2019  16:19:25.  0.014383  1.587195
# 3     9/18/2019  16:19:25.  0.012612  1.604105
# 4     9/18/2019  16:19:25.  0.012451  1.626169
# ...                    ...       ...       ...
# 2043  9/18/2019  16:19:25. -0.046010 -1.606902
# 2044  9/18/2019  16:19:25. -0.048104 -1.629771
# 2045  9/18/2019  16:19:25. -0.046976 -1.652963
# 2046  9/18/2019  16:19:25. -0.046654 -1.668262
# 2047  9/18/2019  16:19:25. -0.042628 -1.690165
#
# [2048 rows x 3 columns]
